# %% [markdown]
# <a href="https://colab.research.google.com/github/Vansh-172/Moving-Object-Detection-System/blob/main/Moving_Object_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO("yolo11m.pt")

# %%
results = model("/content/drive/MyDrive/Identity Documents/Vanshgoyal.JPG", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Identity Documents/Vanshgoyal.JPG: 640x544 1 person, 1733.3ms
# Speed: 3.3ms preprocess, 1733.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/detect/predict-2

# %%
results = model.predict(
    source="/content/drive/MyDrive/Gurugram/video_20260509_173513.mp4",
    save=True,
    conf=0.5
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/199) /content/drive/MyDrive/Gurugram/video_20260509_173513.mp4: 384x640 2 persons, 769.8ms
# video 1/1 (frame 2/199) /content/drive/MyDrive/Gurugram/video_20260509_173513.mp4: 384x640 2 persons, 1 bicycle, 971.3ms
# video 1/1 (frame 3/199) /content/drive/MyDrive/Gurugram/video_20260509_173513.mp4: 384x640 2 persons, 1998.3ms
# ...
